# %% [markdown]
# ### Imports, Functions, and Variables

# %%
import pandas as pd
import numpy as np

# %%
 def workstation_to_agency(workstation_value):
        """Pat's original design for calculating Agency field value"""
        if "sha" in workstation_value:
            return 'SHA'
        elif "ad-geo" in workstation_value:
            return 'DHMH'
        elif "anlt" in workstation_value:
            return 'DOIT'
        elif "bha" in workstation_value:
            return 'DHMH'
        elif "boa" in workstation_value:
            return 'DNR'
        elif "cac" in workstation_value:
            return 'DNR'
        elif "carrhd" in workstation_value:
            return 'DHMH'
        elif "cgla" in workstation_value:
            return 'DNR'
        elif "chart" in workstation_value:
            return 'CHART'
        elif "doit" in workstation_value:
            return 'DOIT'
        elif "dt-nbar" in workstation_value:
            return 'MEMA'
        elif "dtseoc" in workstation_value:
            return 'MEMA'
        elif "f1" in workstation_value:
            return 'MDTA'
        elif "fis" in workstation_value:
            return 'DNR'
        elif "for" in workstation_value:
            return 'DNR'
        elif "hchd" in workstation_value:
            return 'DHMH'
        elif "ideha" in workstation_value:
            return 'DHMH'
        elif "ipr" in workstation_value:
            return 'DNR'
        elif "it" in workstation_value:
            return 'DOIT'
        elif "It-" in workstation_value:
            return 'DOIT'
        elif "its" in workstation_value:
            return 'DNR'
        elif "lap" in workstation_value:
            return 'DNR'
        elif "mcac" in workstation_value:
            return 'MCAC'
        elif "mda" in workstation_value:
            return 'MDA'
        elif "mdp" in workstation_value:
            return 'MDP'
        elif "met" in workstation_value:
            return 'MET'
        elif "mgs" in workstation_value:
            return 'DNR'
        elif "mht" in workstation_value:
            return 'MDP'
        elif "mmccon" in workstation_value:
            return 'MLIS'
        elif "mta" in workstation_value:
            return 'MTA'
        elif "ofkaw" in workstation_value:
            return 'DBED'
        elif "ox" in workstation_value:
            return 'DNR'
        elif "pc-" in workstation_value:
            return 'MDE'
        elif "phpa" in workstation_value:
            return 'DHMH'
        elif "prk" in workstation_value:
            return 'DNR'
        elif "ras" in workstation_value:
            return 'DNR'
        elif "scdd" in workstation_value:
            return 'MDA'
        elif "schd" in workstation_value:
            return 'DHMH'
        elif "t22" in workstation_value:
            return 'MTA'
        elif "t23" in workstation_value:
            return 'MTA'
        elif "t21" in workstation_value:
            return 'MTA'
        elif "whs" in workstation_value:
            return 'DNR'
        elif "brel" in workstation_value:
            return 'COMP'
        elif "w-7" in workstation_value:
            return 'DHCD'
        elif "cechd" in workstation_value:
            return 'DHMH'
        elif "dda-83905" in workstation_value:
            return 'DHMH'
        elif "fha-" in workstation_value:
            return 'DHMH'
        elif "hsia-" in workstation_value:
            return 'DHMH'
        elif "mhcc-" in workstation_value:
            return 'DHMH'
        elif "sandy-b" in workstation_value:
            return 'DHMH'
        elif "wic-000" in workstation_value:
            return 'DHMH'
        elif "wochd-" in workstation_value:
            return 'DHMH'
        elif "geoserv" in workstation_value:
            return 'DHMH'
        elif "vsa-" in workstation_value:
            return 'DHMH'
        elif "000_02_146299" in workstation_value:
            return 'DHR'
        elif "fa62512" in workstation_value:
            return 'DJS'
        elif "dwd27088" in workstation_value:
            return 'DLLR'
        elif "lmai" in workstation_value:
            return 'DLLR'
        elif "oos009" in workstation_value:
            return 'DNR'
        elif "minint-" in workstation_value:
            return 'MDA'
        elif "mdewin" in workstation_value:
            return 'MDE'
        elif "tr-1024352" in workstation_value:
            return 'MDE'
        elif "tr-1024362" in workstation_value:
            return 'MDE'
        elif "tr-1024368" in workstation_value:
            return 'MDE'
        elif "tr-1024371" in workstation_value:
            return 'MDE'
        elif "tr-1024385" in workstation_value:
            return 'MDE'
        elif "tr-1024386" in workstation_value:
            return 'MDE'
        elif "tr-1024388" in workstation_value:
            return 'MDE'
        elif "tr-1024393" in workstation_value:
            return 'MDE'
        elif "q13" in workstation_value:
            return 'MDOT'
        elif "va52450" in workstation_value:
            return 'MDP'
        elif "mdtagis" in workstation_value:
            return 'MDTA'
        elif "lt-thutchison" in workstation_value:
            return 'MEMA'
        elif "meshp" in workstation_value:
            return 'MPA'
        elif "mpa-hp" in workstation_value:
            return 'MPA'
        elif "s530" in workstation_value:
            return 'MPA'
        elif "s535" in workstation_value:
            return 'MPA'
        elif "s536" in workstation_value:
            return 'MPA'
        elif "s538" in workstation_value:
            return 'MPA'
        elif "s541" in workstation_value:
            return 'MPA'
        elif "s542" in workstation_value:
            return 'MPA'
        elif "msp000" in workstation_value:
            return 'MSP'
        elif "s530" in workstation_value:
            return 'MPA'
        elif "sandy-b" in workstation_value:
            return 'DHMH'
        elif "sgatesdlsl1" in workstation_value:
            return 'MLIS'
        elif "skennedydlsl1" in workstation_value:
            return 'MLIS'
        elif "smccullochdlsl1" in workstation_value:
            return 'MLIS'
        elif "srossdlsl1" in workstation_value:
            return 'MLIS'
        elif "ssd-800g1-01" in workstation_value:
            return 'MDP'
        elif "tclarkdlsl1" in workstation_value:
            return 'MLIS'
        elif "tl222845" in workstation_value:
            return 'MTA'
        elif "tl231013" in workstation_value:
            return 'MTA'
        elif "tr-1024" in workstation_value:
            return 'Training'
        elif "training" in workstation_value:
            return 'Training'
        elif "tzimmermandlsl1" in workstation_value:
            return 'MLIS'
        elif "va47" in workstation_value:
            return 'MVA'
        elif "va511" in workstation_value:
            return 'MVA'
        elif "va54" in workstation_value:
            return 'MVA'
        elif "va625" in workstation_value:
            return 'MVA'
        elif "va52450" in workstation_value:
            return 'MDOT'
        elif "vsa-" in workstation_value:
            return 'DHMH'
        elif "wic-00076933" in workstation_value:
            return 'DHMH'
        elif "wochd-7397" in workstation_value:
            return 'DHMH'
        elif "yweissmannmgal1" in workstation_value:
            return 'MLIS'
        elif "wsu00" in workstation_value:
            return 'DNR'
        else:
            return 'Research'

# %%
data_file = r"Example Activity Report Generated by OpenLM.csv"
output_file = r"TEST.xlsx"
fields_to_drop = ["Version", "License Type", "Borrowed", "Server", "Vendor", "Additional Key", "Host Ids", "IP",
                  "Project", "Group", "Usage Time w/in filter period", "Consumed Tokens", "Idle Time (hours)",
                  "Token Usage Time", "Token Usage Time w/in filter period", "Session ID",
                  "Source"]
# fields_of_interest = ["Feature", "Product", "Start Time", "End Time", "Workstation", "User Name", "First Name",
#                       "Last Name", "Email", "Total usage time (hours)", "Usage Time w/in filter period",
#                       "Token Usage Time w/in filter period"]
new_fields = ["Agency", "Date", "Product_Workstation", "Product_Username"]
# excel_date_format = "YYYY-MM-DD"
# excel_datetime_format = "YYYY-MM-DD HH:MM:SS"

# %% [markdown]
# ### Create master dataframe from report csv file

# %%
master_df = pd.read_csv(data_file)

# %% [markdown]
# ### Slim size of dataframe by dropping unneeded fields

# %%
master_df.drop(columns=fields_to_drop, inplace=True)
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 10 columns):
# Feature                     507 non-null object
# Product                     507 non-null object
# Start Time                  507 non-null object
# End Time                    507 non-null object
# Workstation                 507 non-null object
# User Name                   507 non-null object
# First Name                  86 non-null object
# Last Name                   86 non-null object
# Email                       79 non-null object
# Total usage time (hours)    507 non-null float64
# dtypes: float64(1), object(9)
# memory usage: 39.7+ KB

# %% [markdown]
# ### Field Calculations
# #### NOTE: When i try to use f strings or .format to form the concatenated values I encounter weird results.

# %%
# Calculate Product_Workstation field
master_df["Product_Workstation"] = master_df["Product"] + "_" + master_df["Workstation"]

# Calculate Product_Username field
master_df["Product_Username"] = master_df["Product"] + "_" + master_df["User Name"]

# Conver Start and End Time fields
master_df["Start Time"] = pd.to_datetime(arg=master_df["Start Time"], dayfirst=True)
master_df["End Time"] = pd.to_datetime(arg=master_df["End Time"], dayfirst=True)

# Calculate Agency field
master_df["Agency"] = master_df["Workstation"].apply(func=workstation_to_agency)

# %% [markdown]
# ### Unique 'Agency' values and counts

# %%
master_df["Agency"].value_counts()
# Out:
# Research    220
# SHA         136
# DNR          38
# MDA          22
# MTA          18
# CHART        17
# MDE          15
# MDTA         14
# DHMH         11
# DOIT          6
# MDP           6
# MPA           2
# MLIS          2
# Name: Agency, dtype: int64

# %% [markdown]
# ### Look at the records where 'Agency' equals 'Research'

# %%
master_df[(master_df["Agency"] == "Research")]
# Out:
#          Feature          Product          Start Time            End Time  \
# 4       ARC/INFO          ArcInfo 2019-02-05 13:28:00 2019-02-07 09:03:55
# 10      ARC/INFO          ArcInfo 2019-02-06 08:42:14 2019-02-07 09:11:04
# 11          Grid  Spatial Analyst 2019-02-06 08:42:14 2019-02-07 09:11:04
# 30   desktopAdvP      desktopAdvP 2019-02-07 00:01:00 2019-02-07 00:01:26
# 31   desktopAdvP      desktopAdvP 2019-02-07 00:03:00 2019-02-07 00:03:50
# 32   desktopAdvP      desktopAdvP 2019-02-07 00:07:00 2019-02-07 00:07:24
# 33   desktopAdvP      desktopAdvP 2019-02-07 00:10:00 2019-02-07 00:10:58
# 34   desktopAdvP      desktopAdvP 2019-02-07 00:13:00 2019-02-07 00:13:21
# 35   desktopAdvP      desktopAdvP 2019-02-07 00:16:00 2019-02-07 00:16:55
# 36   desktopAdvP      desktopAdvP 2019-02-07 00:22:00 2019-02-07 00:22:50
# 37   desktopAdvP      desktopAdvP 2019-02-07 00:26:00 2019-02-07 00:26:24
# 38   desktopAdvP      desktopAdvP 2019-02-07 00:32:00 2019-02-07 00:32:20
# 39   desktopAdvP      desktopAdvP 2019-02-07 00:35:00 2019-02-07 00:35:54
# 40   desktopAdvP      desktopAdvP 2019-02-07 00:39:00 2019-02-07 00:39:28
# 42   desktopAdvP      desktopAdvP 2019-02-07 00:41:00 2019-02-07 00:41:52
# 45   desktopAdvP      desktopAdvP 2019-02-07 00:45:00 2019-02-07 00:45:26
# 46   desktopAdvP      desktopAdvP 2019-02-07 00:47:00 2019-02-07 00:47:50
# 47   desktopAdvP      desktopAdvP 2019-02-07 00:51:00 2019-02-07 00:51:23
# 48   desktopAdvP      desktopAdvP 2019-02-07 00:54:00 2019-02-07 00:54:58
# 49   desktopAdvP      desktopAdvP 2019-02-07 00:57:00 2019-02-07 00:57:21
# 50   desktopAdvP      desktopAdvP 2019-02-07 01:00:00 2019-02-07 01:00:55
# 51   desktopAdvP      desktopAdvP 2019-02-07 01:06:00 2019-02-07 01:06:50
# 52   desktopAdvP      desktopAdvP 2019-02-07 01:10:00 2019-02-07 01:10:24
# 53   desktopAdvP      desktopAdvP 2019-02-07 01:13:00 2019-02-07 01:13:58
# 55   desktopAdvP      desktopAdvP 2019-02-07 01:16:00 2019-02-07 01:16:22
# 56   desktopAdvP      desktopAdvP 2019-02-07 01:19:00 2019-02-07 01:19:56
# 57   desktopAdvP      desktopAdvP 2019-02-07 01:25:00 2019-02-07 01:25:51
# 58   desktopAdvP      desktopAdvP 2019-02-07 01:29:00 2019-02-07 01:29:25
# 60   desktopAdvP      desktopAdvP 2019-02-07 01:35:00 2019-02-07 01:35:21
# 61   desktopAdvP      desktopAdvP 2019-02-07 01:38:00 2019-02-07 01:38:55
# ..           ...              ...                 ...                 ...
# 415  desktopAdvP      desktopAdvP 2019-02-07 10:10:00 2019-02-07 10:10:57
# 418  desktopAdvP      desktopAdvP 2019-02-07 10:13:00 2019-02-07 10:13:20
# 421  desktopAdvP      desktopAdvP 2019-02-07 10:16:00 2019-02-07 10:16:57
# 425     ARC/INFO          ArcInfo 2019-02-07 10:18:09 2019-02-07 10:24:09
# 426  desktopAdvP      desktopAdvP 2019-02-07 10:19:00 2019-02-07 10:19:20
# 430     ARC/INFO          ArcInfo 2019-02-07 10:20:00 2019-02-07 11:06:10
# 431  desktopAdvP      desktopAdvP 2019-02-07 10:22:00 2019-02-07 10:22:57
# 436  desktopAdvP      desktopAdvP 2019-02-07 10:25:00 2019-02-07 10:25:21
# 437  desktopAdvP      desktopAdvP 2019-02-07 10:26:00 2019-02-07 10:26:33
# 439  desktopAdvP      desktopAdvP 2019-02-07 10:28:00 2019-02-07 10:28:56
# 442       Viewer          ArcView 2019-02-07 10:30:09 2019-02-07 10:34:55
# 443  desktopAdvP      desktopAdvP 2019-02-07 10:32:00 2019-02-07 10:32:31
# 454  desktopAdvP      desktopAdvP 2019-02-07 10:34:00 2019-02-07 10:34:55
# 467  desktopAdvP      desktopAdvP 2019-02-07 10:40:00 2019-02-07 10:40:55
# 471  desktopAdvP      desktopAdvP 2019-02-07 10:44:00 2019-02-07 10:44:31
# 473       Viewer          ArcView 2019-02-07 10:45:00 2019-02-07 10:49:20
# 475  desktopAdvP      desktopAdvP 2019-02-07 10:46:00 2019-02-07 10:46:56
# 476  desktopAdvP      desktopAdvP 2019-02-07 10:49:00 2019-02-07 10:49:20
# 479  desktopAdvP      desktopAdvP 2019-02-07 10:50:00 2019-02-07 10:50:32
# 482  desktopAdvP      desktopAdvP 2019-02-07 10:52:00 2019-02-07 10:52:57
# 483  desktopAdvP      desktopAdvP 2019-02-07 10:55:00 2019-02-07 10:55:21
# 485  desktopAdvP      desktopAdvP 2019-02-07 10:58:00 2019-02-07 10:58:56
# 489  desktopAdvP      desktopAdvP 2019-02-07 11:01:00 2019-02-07 11:01:20
# 490  desktopAdvP      desktopAdvP 2019-02-07 11:02:00 2019-02-07 11:02:32
# 491     ARC/INFO          ArcInfo 2019-02-07 11:03:00 2019-02-07 11:21:49
# 492  desktopAdvP      desktopAdvP 2019-02-07 11:05:00 2019-02-07 11:05:00
# 496  desktopAdvP      desktopAdvP 2019-02-07 11:07:00 2019-02-07 11:07:23
# 498  desktopAdvP      desktopAdvP 2019-02-07 11:13:00 2019-02-07 11:13:23
# 503  desktopAdvP      desktopAdvP 2019-02-07 11:16:00 2019-02-07 11:17:01
# 506  desktopAdvP      desktopAdvP 2019-02-07 11:19:00 2019-02-07 11:19:25
#
#          Workstation           User Name First Name   Last Name  \
# 4        dnr-90xnps1         bgreenfield      Brett  Greenfield
# 10       dnr-f6j7jr2              aclark  Alexander       Clark
# 11       dnr-f6j7jr2              aclark  Alexander       Clark
# 30   gis-util-imap1p  visualcron-service        NaN         NaN
# 31   gis-util-imap1p  visualcron-service        NaN         NaN
# 32   gis-util-imap1p  visualcron-service        NaN         NaN
# 33   gis-util-imap1p  visualcron-service        NaN         NaN
# 34   gis-util-imap1p  visualcron-service        NaN         NaN
# 35   gis-util-imap1p  visualcron-service        NaN         NaN
# 36   gis-util-imap1p  visualcron-service        NaN         NaN
# 37   gis-util-imap1p  visualcron-service        NaN         NaN
# 38   gis-util-imap1p  visualcron-service        NaN         NaN
# 39   gis-util-imap1p  visualcron-service        NaN         NaN
# 40   gis-util-imap1p  visualcron-service        NaN         NaN
# 42   gis-util-imap1p  visualcron-service        NaN         NaN
# 45   gis-util-imap1p  visualcron-service        NaN         NaN
# 46   gis-util-imap1p  visualcron-service        NaN         NaN
# 47   gis-util-imap1p  visualcron-service        NaN         NaN
# 48   gis-util-imap1p  visualcron-service        NaN         NaN
# 49   gis-util-imap1p  visualcron-service        NaN         NaN
# 50   gis-util-imap1p  visualcron-service        NaN         NaN
# 51   gis-util-imap1p  visualcron-service        NaN         NaN
# 52   gis-util-imap1p  visualcron-service        NaN         NaN
# 53   gis-util-imap1p  visualcron-service        NaN         NaN
# 55   gis-util-imap1p  visualcron-service        NaN         NaN
# 56   gis-util-imap1p  visualcron-service        NaN         NaN
# 57   gis-util-imap1p  visualcron-service        NaN         NaN
# 58   gis-util-imap1p  visualcron-service        NaN         NaN
# 60   gis-util-imap1p  visualcron-service        NaN         NaN
# 61   gis-util-imap1p  visualcron-service        NaN         NaN
# ..               ...                 ...        ...         ...
# 415  gis-util-imap1p  visualcron-service        NaN         NaN
# 418  gis-util-imap1p  visualcron-service        NaN         NaN
# 421  gis-util-imap1p  visualcron-service        NaN         NaN
# 425     dnr-r901k5cw            asantoro        NaN         NaN
# 426  gis-util-imap1p  visualcron-service        NaN         NaN
# 430  gis-ags-imap01s     aa.Samuel.Hayek        NaN         NaN
# 431  gis-util-imap1p  visualcron-service        NaN         NaN
# 436  gis-util-imap1p  visualcron-service        NaN         NaN
# 437  gis-util-imap1p  visualcron-service        NaN         NaN
# 439  gis-util-imap1p  visualcron-service        NaN         NaN
# 442      mde-cqlhk02              fklemm    Francis       Klemm
# 443  gis-util-imap1p  visualcron-service        NaN         NaN
# 454  gis-util-imap1p  visualcron-service        NaN         NaN
# 467  gis-util-imap1p  visualcron-service        NaN         NaN
# 471  gis-util-imap1p  visualcron-service        NaN         NaN
# 473     epiercedlsl1                erip        NaN         NaN
# 475  gis-util-imap1p  visualcron-service        NaN         NaN
# 476  gis-util-imap1p  visualcron-service        NaN         NaN
# 479  gis-util-imap1p  visualcron-service        NaN         NaN
# 482  gis-util-imap1p  visualcron-service        NaN         NaN
# 483  gis-util-imap1p  visualcron-service        NaN         NaN
# 485  gis-util-imap1p  visualcron-service        NaN         NaN
# 489  gis-util-imap1p  visualcron-service        NaN         NaN
# 490  gis-util-imap1p  visualcron-service        NaN         NaN
# 491      dnr-cks65q2            lserafin        NaN         NaN
# 492  gis-util-imap1p  visualcron-service        NaN         NaN
# 496  gis-util-imap1p  visualcron-service        NaN         NaN
# 498  gis-util-imap1p  visualcron-service        NaN         NaN
# 503  gis-util-imap1p  visualcron-service        NaN         NaN
# 506  gis-util-imap1p  visualcron-service        NaN         NaN
#
#                            Email  Total usage time (hours)  \
# 4    bgreenfield@dnr.state.md.us                     43.58
# 10        aclark@dnr.state.md.us                     24.48
# 11        aclark@dnr.state.md.us                     24.48
# 30                           NaN                      0.00
# 31                           NaN                      0.00
# 32                           NaN                      0.00
# 33                           NaN                      0.00
# 34                           NaN                      0.00
# 35                           NaN                      0.00
# 36                           NaN                      0.00
# 37                           NaN                      0.00
# 38                           NaN                      0.00
# 39                           NaN                      0.00
# 40                           NaN                      0.00
# 42                           NaN                      0.00
# 45                           NaN                      0.00
# 46                           NaN                      0.00
# 47                           NaN                      0.00
# 48                           NaN                      0.00
# 49                           NaN                      0.00
# 50                           NaN                      0.00
# 51                           NaN                      0.00
# 52                           NaN                      0.00
# 53                           NaN                      0.00
# 55                           NaN                      0.00
# 56                           NaN                      0.00
# 57                           NaN                      0.00
# 58                           NaN                      0.00
# 60                           NaN                      0.00
# 61                           NaN                      0.00
# ..                           ...                       ...
# 415                          NaN                      0.00
# 418                          NaN                      0.00
# 421                          NaN                      0.00
# 425                          NaN                      0.10
# 426                          NaN                      0.00
# 430                          NaN                      0.76
# 431                          NaN                      0.00
# 436                          NaN                      0.00
# 437                          NaN                      0.00
# 439                          NaN                      0.00
# 442   francis.klemm@maryland.gov                      0.06
# 443                          NaN                      0.00
# 454                          NaN                      0.00
# 467                          NaN                      0.00
# 471                          NaN                      0.00
# 473                          NaN                      0.06
# 475                          NaN                      0.00
# 476                          NaN                      0.00
# 479                          NaN                      0.00
# 482                          NaN                      0.00
# 483                          NaN                      0.00
# 485                          NaN                      0.00
# 489                          NaN                      0.00
# 490                          NaN                      0.00
# 491                          NaN                      0.30
# 492                          NaN                      0.00
# 496                          NaN                      0.00
# 498                          NaN                      0.00
# 503                          NaN                      0.01
# 506                          NaN                      0.00
#
#              Product_Workstation                Product_Username    Agency
# 4            ArcInfo_dnr-90xnps1             ArcInfo_bgreenfield  Research
# 10           ArcInfo_dnr-f6j7jr2                  ArcInfo_aclark  Research
# 11   Spatial Analyst_dnr-f6j7jr2          Spatial Analyst_aclark  Research
# 30   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 31   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 32   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 33   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 34   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 35   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 36   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 37   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 38   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 39   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 40   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 42   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 45   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 46   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 47   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 48   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 49   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 50   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 51   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 52   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 53   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 55   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 56   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 57   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 58   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 60   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 61   desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# ..                           ...                             ...       ...
# 415  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 418  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 421  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 425         ArcInfo_dnr-r901k5cw                ArcInfo_asantoro  Research
# 426  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 430      ArcInfo_gis-ags-imap01s         ArcInfo_aa.Samuel.Hayek  Research
# 431  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 436  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 437  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 439  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 442          ArcView_mde-cqlhk02                  ArcView_fklemm  Research
# 443  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 454  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 467  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 471  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 473         ArcView_epiercedlsl1                    ArcView_erip  Research
# 475  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 476  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 479  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 482  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 483  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 485  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 489  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 490  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 491          ArcInfo_dnr-cks65q2                ArcInfo_lserafin  Research
# 492  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 496  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 498  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 503  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
# 506  desktopAdvP_gis-util-imap1p  desktopAdvP_visualcron-service  Research
#
# [220 rows x 13 columns]

# %% [markdown]
# ### Product_Workstation Report

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 13 columns):
# Feature                     507 non-null object
# Product                     507 non-null object
# Start Time                  507 non-null datetime64[ns]
# End Time                    507 non-null datetime64[ns]
# Workstation                 507 non-null object
# User Name                   507 non-null object
# First Name                  86 non-null object
# Last Name                   86 non-null object
# Email                       79 non-null object
# Total usage time (hours)    507 non-null float64
# Product_Workstation         507 non-null object
# Product_Username            507 non-null object
# Agency                      507 non-null object
# dtypes: datetime64[ns](2), float64(1), object(10)
# memory usage: 51.6+ KB

# %%
# product_workstation_df = master_df[["Agency", "Product_Workstation"]]
agency_product_gbdf = master_df.groupby(by=["Agency", "Product"], axis=0)

# %% [markdown]
# # No clue if this is meaningful. Assess next week. STOPPED HERE

# %%
agency_product_gbdf.aggregate(np.sum)
# Out:
#                                  Total usage time (hours)
# Agency   Product
# CHART    ArcInfo                                     0.00
# DHMH     ArcInfo                                    16.94
#          ArcView                                     2.98
#          VBA                                         0.95
#          desktopAdvP                                 1.98
# DNR      3DAnalyst                                   2.45
#          3DAnalystP                                 14.26
#          ArcEditor                                   1.09
#          ArcInfo                                    20.92
#          ArcView                                    55.61
#          Spatial Analyst                            23.34
#          VBA                                        19.28
#          dataReviewerP                              14.26
#          desktopAdvP                                14.26
#          geostatAnalystP                            14.26
#          networkAnalystP                            14.26
#          spatialAnalystP                            14.26
# DOIT     ArcInfo                                     2.95
# MDA      3DAnalyst                                   0.10
#          ArcInfo                                     0.11
#          ArcView                                     6.07
#          GeoStats                                    0.10
#          Network Analyst                             0.10
#          Publisher                                   0.10
#          Spatial Analyst                             0.10
#          desktopAdvP                                 0.25
# MDE      3DAnalyst                                   0.08
#          ArcEditor                                   0.11
#          ArcInfo                                     0.30
#          ArcView                                    52.02
# ...                                                   ...
# MTA      ArcView                                     0.01
#          Network Analyst                             0.41
#          Spatial Analyst                             0.15
#          desktopAdvP                                 1.36
#          geostatAnalystP                             1.36
#          networkAnalystP                             1.36
#          spatialAnalystP                             1.36
# Research 3DAnalyst                                   0.76
#          ArcEditor                                   0.87
#          ArcInfo                                    82.73
#          ArcView                                     6.88
#          PLTS GIS Data ReViewer                      4.11
#          Spatial Analyst                            28.20
#          desktopAdvP                                 0.29
# SHA      3DAnalyst                                  37.05
#          3DAnalystP                                  2.11
#          ArcInfo                                    59.34
#          ArcView                                    31.63
#          GeoStats                                    1.43
#          Highways                                  781.47
#          Network Analyst                             1.43
#          Publisher                                   1.43
#          Spatial Analyst                            32.27
#          VBA                                        60.03
#          dataReviewerP                               0.05
#          desktopAdvP                                 1.64
#          desktopStdP                                 2.36
#          geostatAnalystP                             2.06
#          networkAnalystP                             0.05
#          spatialAnalystP                             2.11
#
# [76 rows x 1 columns]
