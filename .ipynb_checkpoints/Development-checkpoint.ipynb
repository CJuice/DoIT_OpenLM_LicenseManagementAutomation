# %% [markdown]
# # Imports, Functions, and Variables

# %%
import pandas as pd
import numpy as np

# Options for data file to process. Size varies on length of time queried for report
# data_file = r"Example Activity Report Generated by OpenLM 1day.csv"
# data_file = r"Example Activity Report Generated by OpenLM NOVtoFEB.csv"
data_file = r"Example Activity Report Generated by OpenLM SEPTtoFEB.csv"

fields_to_drop = ["Version", "License Type", "Borrowed", "Server", "Vendor", "Additional Key", "Host Ids", "IP",
                  "Project", "Group", "Usage Time w/in filter period", "Consumed Tokens", "Idle Time (hours)",
                  "Token Usage Time", "Token Usage Time w/in filter period", "Session ID",
                  "Source"]
column_datatypes = {"Feature": str, "Product": str, "Start Time": str, "End Time": str, "Workstation": str,
                    "User Name": str, "First Name": str, "Last Name": str, "Email": str, 
                    "Total usage time (hours)": float}
workstation_agency_substitutions_file = r"WorkstationToAgency_SubstitutionsList.csv"
product_label_substitutions_file = r"ProductCodeToProductLabel_SubstitutionsList.csv"

# %% [markdown]
# # Process Data
# #### Create Master Dataframe from OpenLM Report (.csv) of Interest

# %%
master_df = pd.read_csv(filepath_or_buffer=data_file, dtype=str)

# %% [markdown]
# #### Slim Size of Dataframe by Dropping Unneeded Fields

# %%
master_df.drop(columns=fields_to_drop, inplace=True)

# %%
master_df
# Out:
#                Feature                 Product           Start Time  \
# 0               Editor               ArcEditor  18/07/2018 20:59:18
# 1             ARC/INFO                 ArcInfo  26/07/2018 15:25:10
# 2                  TIN               3DAnalyst  04/09/2018 08:43:00
# 3             ArcStorm                ArcStorm  26/07/2018 15:25:10
# 4       ArcStormEnable          ArcStormEnable  26/07/2018 15:25:10
# 5                MrSID                   MrSID  26/07/2018 15:25:10
# 6             Plotting                Plotting  26/07/2018 15:25:10
# 7              TIFFLZW                 TIFFLZW  26/07/2018 15:25:10
# 8             ARC/INFO                 ArcInfo  27/07/2018 16:16:00
# 9                 Grid         Spatial Analyst  27/07/2018 16:16:00
# 10            ARC/INFO                 ArcInfo  01/08/2018 10:00:00
# 11            ARC/INFO                 ArcInfo  01/08/2018 11:29:00
# 12            ARC/INFO                 ArcInfo  02/08/2018 07:08:10
# 13         desktopAdvP             desktopAdvP  07/08/2018 13:06:00
# 14            Highways                Highways  09/08/2018 11:30:06
# 15         desktopAdvP             desktopAdvP  09/08/2018 16:02:00
# 16              Viewer                 ArcView  14/08/2018 12:42:01
# 17            ARC/INFO                 ArcInfo  15/08/2018 08:26:17
# 18            ArcStorm                ArcStorm  15/08/2018 08:26:17
# 19      ArcStormEnable          ArcStormEnable  15/08/2018 08:26:17
# 20               MrSID                   MrSID  15/08/2018 08:26:17
# 21            Plotting                Plotting  15/08/2018 08:26:17
# 22             TIFFLZW                 TIFFLZW  15/08/2018 08:26:17
# 23                Grid         Spatial Analyst  15/08/2018 14:10:00
# 24                 TIN               3DAnalyst  15/08/2018 14:10:00
# 25            Highways                Highways  16/08/2018 07:57:00
# 26              Viewer                 ArcView  16/08/2018 09:10:00
# 27              Viewer                 ArcView  16/08/2018 15:29:00
# 28            ARC/INFO                 ArcInfo  17/08/2018 06:33:26
# 29        DataReViewer  PLTS GIS Data ReViewer  20/08/2018 09:37:00
# ...                ...                     ...                  ...
# 159135             TIN               3DAnalyst  12/02/2019 10:05:00
# 159136             VBA                     VBA  12/02/2019 10:05:00
# 159137          Viewer                 ArcView  12/02/2019 10:06:00
# 159138     desktopAdvP             desktopAdvP  12/02/2019 10:08:00
# 159139        ARC/INFO                 ArcInfo  12/02/2019 10:09:04
# 159140             VBA                     VBA  12/02/2019 10:09:04
# 159141     desktopAdvP             desktopAdvP  12/02/2019 10:11:00
# 159142          Editor               ArcEditor  12/02/2019 10:11:28
# 159143     desktopAdvP             desktopAdvP  12/02/2019 10:13:00
# 159144     desktopAdvP             desktopAdvP  12/02/2019 10:17:00
# 159145     desktopAdvP             desktopAdvP  12/02/2019 10:19:00
# 159146     desktopAdvP             desktopAdvP  12/02/2019 10:23:00
# 159147     desktopAdvP             desktopAdvP  12/02/2019 10:24:00
# 159148        ARC/INFO                 ArcInfo  12/02/2019 10:25:00
# 159149          Viewer                 ArcView  12/02/2019 10:26:00
# 159150     desktopAdvP             desktopAdvP  12/02/2019 10:29:00
# 159151        ARC/INFO                 ArcInfo  12/02/2019 10:30:00
# 159152     desktopAdvP             desktopAdvP  12/02/2019 10:30:00
# 159153          Editor               ArcEditor  12/02/2019 10:30:35
# 159154     desktopAdvP             desktopAdvP  12/02/2019 10:32:00
# 159155        ARC/INFO                 ArcInfo  12/02/2019 10:36:00
# 159156     desktopAdvP             desktopAdvP  12/02/2019 10:36:00
# 159157     desktopAdvP             desktopAdvP  12/02/2019 10:38:00
# 159158     desktopAdvP             desktopAdvP  12/02/2019 10:39:00
# 159159     desktopAdvP             desktopAdvP  12/02/2019 10:42:00
# 159160     desktopAdvP             desktopAdvP  12/02/2019 10:45:00
# 159161        ARC/INFO                 ArcInfo  12/02/2019 10:45:00
# 159162     desktopAdvP             desktopAdvP  12/02/2019 10:45:00
# 159163     desktopAdvP             desktopAdvP  12/02/2019 10:48:00
# 159164     desktopAdvP             desktopAdvP  12/02/2019 10:50:00
#
#                    End Time      Workstation             User Name First Name  \
# 0       05/09/2018 21:21:00   00102644-w7-64  activated license(s)        NaN
# 1       05/09/2018 21:21:00  mhtfieldtablet2  activated license(s)        NaN
# 2       04/09/2018 08:50:55   shaoppelt79047               jwhite4        Joe
# 3       05/09/2018 21:21:00  mhtfieldtablet2  activated license(s)        NaN
# 4       05/09/2018 21:21:00  mhtfieldtablet2  activated license(s)        NaN
# 5       05/09/2018 21:21:00  mhtfieldtablet2  activated license(s)        NaN
# 6       05/09/2018 21:21:00  mhtfieldtablet2  activated license(s)        NaN
# 7       05/09/2018 21:21:00  mhtfieldtablet2  activated license(s)        NaN
# 8       04/09/2018 19:09:00   doit-memaags01       wmelville.admin        NaN
# 9       04/09/2018 19:09:00   doit-memaags01       wmelville.admin        NaN
# 10      05/09/2018 18:58:00  doit-imagegis01          msokol.admin        NaN
# 11      04/09/2018 20:27:00  gis-ags-image1p      aa.matthew.sokol        NaN
# 12      04/09/2018 19:23:58  gis-ags-appd01s      aa.jessie.cahoon        NaN
# 13      05/09/2018 21:21:00  desktop-digbge6  activated license(s)        NaN
# 14      04/09/2018 12:27:11     shaoppepc549  activated license(s)        NaN
# 15      05/09/2018 21:21:00       mda24080lt  activated license(s)        NaN
# 16      05/09/2018 21:21:00       whs0097601  activated license(s)        NaN
# 17      05/09/2018 21:21:00       mgs0097899  activated license(s)        NaN
# 18      05/09/2018 21:21:00       mgs0097899  activated license(s)        NaN
# 19      05/09/2018 21:21:00       mgs0097899  activated license(s)        NaN
# 20      05/09/2018 21:21:00       mgs0097899  activated license(s)        NaN
# 21      05/09/2018 21:21:00       mgs0097899  activated license(s)        NaN
# 22      05/09/2018 21:21:00       mgs0097899  activated license(s)        NaN
# 23      05/09/2018 21:21:00     mda5042102lt  activated license(s)        NaN
# 24      05/09/2018 21:21:00     mda5042102lt  activated license(s)        NaN
# 25      05/09/2018 21:21:00     shaoppepc570  activated license(s)        NaN
# 26      05/09/2018 21:21:00       for0076941  activated license(s)        NaN
# 27      05/09/2018 21:21:00       pc-2002657  activated license(s)        NaN
# 28      04/09/2018 20:48:00  gis-ags-appd01p      aa.jessie.cahoon        NaN
# 29      05/09/2018 21:21:00     mda5042104lt  activated license(s)        NaN
# ...                     ...              ...                   ...        ...
# 159135  12/02/2019 10:36:31   shaoedpce10477                 lresh        NaN
# 159136  12/02/2019 10:36:31   shaoedpce10477                 lresh        NaN
# 159137  12/02/2019 10:16:16  shaoppepce10246            RChojnacki        NaN
# 159138  12/02/2019 10:08:00  gis-util-imap1p    visualcron-service        NaN
# 159139  12/02/2019 10:10:15  shaoppepcc73741                jdietz      Julia
# 159140  12/02/2019 10:10:15  shaoppepcc73741                jdietz      Julia
# 159141  12/02/2019 10:11:27  gis-util-imap1p    visualcron-service        NaN
# 159142  12/02/2019 10:23:25      mde-9bcwsg2              hmerritt    Heather
# 159143  12/02/2019 10:13:51  gis-util-imap1p    visualcron-service        NaN
# 159144  12/02/2019 10:17:27  gis-util-imap1p    visualcron-service        NaN
# 159145  12/02/2019 10:19:50  gis-util-imap1p    visualcron-service        NaN
# 159146  12/02/2019 10:23:25  gis-util-imap1p    visualcron-service        NaN
# 159147  12/02/2019 10:24:36  gis-util-imap1p    visualcron-service        NaN
# 159148  12/02/2019 10:36:31      dnr-cks65q2              lserafin        NaN
# 159149  12/02/2019 10:35:19      mde-6s3zhm2            kmajchrzak       Kate
# 159150  12/02/2019 10:29:22  gis-util-imap1p    visualcron-service        NaN
# 159151  12/02/2019 10:30:34     shaoppevd628         shahisdappmgr        NaN
# 159152  12/02/2019 10:30:34  gis-util-imap1p    visualcron-service        NaN
# 159153  12/02/2019 10:50:50      mde-9bcwsg2              hmerritt    Heather
# 159154  12/02/2019 10:32:57  gis-util-imap1p    visualcron-service        NaN
# 159155  12/02/2019 10:44:52     cechd-5219lt                caston        NaN
# 159156  12/02/2019 10:36:31  gis-util-imap1p    visualcron-service        NaN
# 159157  12/02/2019 10:38:54  gis-util-imap1p    visualcron-service        NaN
# 159158  12/02/2019 10:40:06  gis-util-imap1p    visualcron-service        NaN
# 159159  12/02/2019 10:42:29  gis-util-imap1p    visualcron-service        NaN
# 159160  12/02/2019 10:45:00  gis-util-imap1p    visualcron-service        NaN
# 159161  12/02/2019 10:46:04     shaoppevd628         shahisdappmgr        NaN
# 159162  12/02/2019 10:46:04  gis-util-imap1p    visualcron-service        NaN
# 159163  12/02/2019 10:48:27  gis-util-imap1p    visualcron-service        NaN
# 159164  12/02/2019 10:50:50  gis-util-imap1p    visualcron-service        NaN
#
#         Last Name                         Email Total usage time (hours)
# 0             NaN                           NaN                 1,176.36
# 1             NaN                           NaN                   989.93
# 2           White       jwhite4@sha.state.md.us                     0.11
# 3             NaN                           NaN                   989.93
# 4             NaN                           NaN                   989.93
# 5             NaN                           NaN                   989.93
# 6             NaN                           NaN                   989.93
# 7             NaN                           NaN                   989.93
# 8             NaN                           NaN                   938.88
# 9             NaN                           NaN                   938.88
# 10            NaN                           NaN                   848.96
# 11            NaN                           NaN                   824.96
# 12            NaN                           NaN                   804.25
# 13            NaN                           NaN                   704.25
# 14            NaN                           NaN                   624.95
# 15            NaN                           NaN                   653.31
# 16            NaN                           NaN                   536.65
# 17            NaN                           NaN                   516.91
# 18            NaN                           NaN                   516.91
# 19            NaN                           NaN                   516.91
# 20            NaN                           NaN                   516.91
# 21            NaN                           NaN                   516.91
# 22            NaN                           NaN                   516.91
# 23            NaN                           NaN                   511.18
# 24            NaN                           NaN                   511.18
# 25            NaN                           NaN                   493.40
# 26            NaN                           NaN                   492.18
# 27            NaN                           NaN                   485.86
# 28            NaN                           NaN                   446.25
# 29            NaN                           NaN                   395.73
# ...           ...                           ...                      ...
# 159135        NaN                           NaN                     0.51
# 159136        NaN                           NaN                     0.51
# 159137        NaN                           NaN                     0.16
# 159138        NaN                           NaN                     0.00
# 159139      Dietz        jdietz@sha.state.md.us                     0.01
# 159140      Dietz        jdietz@sha.state.md.us                     0.01
# 159141        NaN                           NaN                     0.00
# 159142    Merritt  heather.merritt@maryland.gov                     0.20
# 159143        NaN                           NaN                     0.00
# 159144        NaN                           NaN                     0.00
# 159145        NaN                           NaN                     0.00
# 159146        NaN                           NaN                     0.00
# 159147        NaN                           NaN                     0.00
# 159148        NaN                           NaN                     0.18
# 159149  Majchrzak   kate.majchrzak@maryland.gov                     0.15
# 159150        NaN                           NaN                     0.00
# 159151        NaN                           NaN                     0.00
# 159152        NaN                           NaN                     0.00
# 159153    Merritt  heather.merritt@maryland.gov                     0.33
# 159154        NaN                           NaN                     0.00
# 159155        NaN                           NaN                     0.13
# 159156        NaN                           NaN                     0.00
# 159157        NaN                           NaN                     0.00
# 159158        NaN                           NaN                     0.01
# 159159        NaN                           NaN                     0.00
# 159160        NaN                           NaN                     0.00
# 159161        NaN                           NaN                     0.01
# 159162        NaN                           NaN                     0.01
# 159163        NaN                           NaN                     0.00
# 159164        NaN                           NaN                     0.00
#
# [159165 rows x 10 columns]

# %%
# clean_commas_from_usage_time. pandas.DataFrame.replace wasn't working to find comma in string ??
def replace_commas(value):
    value = str(value)
    if "," in value:
        value =value.replace(",", "")
    return float(value)

master_df["Total usage time (hours)"] = master_df["Total usage time (hours)"].apply(func=replace_commas)
master_df = master_df.astype(dtype=column_datatypes)
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159165 entries, 0 to 159164
# Data columns (total 10 columns):
# Feature                     159165 non-null object
# Product                     159165 non-null object
# Start Time                  159165 non-null object
# End Time                    159165 non-null object
# Workstation                 159165 non-null object
# User Name                   159165 non-null object
# First Name                  159165 non-null object
# Last Name                   159165 non-null object
# Email                       159165 non-null object
# Total usage time (hours)    159165 non-null float64
# dtypes: float64(1), object(9)
# memory usage: 12.1+ MB

# %% [markdown]
# ### Field Calculations
# NOTE: When i try to use f strings or .format to form the concatenated values I encounter weird results.

# %% [markdown]
# #### Get Product Label Values as a Python Dictionary

# %%
product_label_substitutions_df = pd.read_csv(filepath_or_buffer=product_label_substitutions_file)
product_label_substitutions_df.set_index("VALUE", inplace=True)
product_label_substitutions_dict = product_label_substitutions_df.to_dict(orient="dict")["REPLACEMENT"]

# %%
# Replace Product Code values with Product Label replacements.
unrecognized_values_set = set()
def product_code_to_label(value):
    try:
        value = product_label_substitutions_dict[value]
    except KeyError:
        value = value.strip("*") # In case ran this step before and already has an '*'
        unrecognized_values_set.add(value)
        value = "*" + value
    return value
master_df["Product"] = master_df["Product"].apply(func=product_code_to_label)

# %% [markdown]
# #### Unrecognized Product Names. No Corresponding Product Label Substitution Value

# %%
# If no unrecognized values then you will see 'set()' printed out
unrecognized_values_set
# Out:
# set()

# %% [markdown]
# #### Get Workstation Substitution Values as a Python Dictionary

# %%
workstation_substitutions_df = pd.read_csv(filepath_or_buffer=workstation_agency_substitutions_file)
workstation_substitutions_df.set_index("VALUE", inplace=True)
workstation_substitutions_dict = workstation_substitutions_df.to_dict(orient="dict")["REPLACEMENT"]

# %% [markdown]
# #### Add New Fields and Calculate

# %%
# Calculate Product_Workstation field
master_df["Product_Workstation"] = master_df["Product"] + "_" + master_df["Workstation"]

# Calculate Product_Username field
master_df["Product_Username"] = master_df["Product"] + "_" + master_df["User Name"]

# Convert Start and End Time fields
master_df["Start Time"] = pd.to_datetime(arg=master_df["Start Time"], dayfirst=True)
master_df["End Time"] = pd.to_datetime(arg=master_df["End Time"], dayfirst=True)

# Calculate Date field from datetime object. For Peak Usage Report
master_df["Date"] = master_df["End Time"].apply(lambda x: x.strftime("%Y%m%d"))

# %%
# Calculate Agency field
def workstation_to_agency(workstation_value):
    result = "Research"
    for key, value in workstation_substitutions_dict.items():
        if key in workstation_value:
            result = value
            break
        else:
            continue
    return result

# %%
master_df["Agency"] = master_df["Workstation"].apply(func=workstation_to_agency)
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159165 entries, 0 to 159164
# Data columns (total 14 columns):
# Feature                     159165 non-null object
# Product                     159165 non-null object
# Start Time                  159165 non-null datetime64[ns]
# End Time                    159165 non-null datetime64[ns]
# Workstation                 159165 non-null object
# User Name                   159165 non-null object
# First Name                  159165 non-null object
# Last Name                   159165 non-null object
# Email                       159165 non-null object
# Total usage time (hours)    159165 non-null float64
# Product_Workstation         159165 non-null object
# Product_Username            159165 non-null object
# Date                        159165 non-null object
# Agency                      159165 non-null object
# dtypes: datetime64[ns](2), float64(1), object(11)
# memory usage: 17.0+ MB

# %%
# master_df

# %% [markdown]
# ### Quick Evaluations
# #### Unique 'Agency' values and counts

# %%
master_df["Agency"].value_counts()
# Out:
# SHA         49235
# DNR         34403
# MDE         24411
# Research     8931
# MDA          7205
# MDP          6494
# MTA          6455
# DOIT         5859
# DHMH         5189
# CHART        3617
# MPA          1884
# COMP         1750
# MDTA         1640
# MDOT          563
# MAA           548
# MLIS          520
# DLLR          256
# MSP            74
# MEMA           65
# MET            50
# DBED           15
# MVA             1
# Name: Agency, dtype: int64

# %% [markdown]
# #### See Full Records for where 'Agency' equals 'Research'

# %%
# master_df[(master_df["Agency"] == "Research")][["Product_Workstation", "Agency"]]

# %% [markdown]
# #### See Workstation Substitutions Values

# %%
# workstation_substitutions_dict

# %% [markdown]
# #### See Unique Agency Codes Where Substitution Resulted in 'Research'

# %%
# master_df[(master_df["Agency"] == "Research")]["Workstation"].unique()

# %% [markdown]
# # Report Generation
# ## Product_Workstation Report

# %% [markdown]
# NOTE: The .agg() function is applied to entire dataframe but only numeric fields are evaluated.
# The 'Total usage time (hours)' column is the only numeric column. The output is what we are seeking
# but if another numeric field was added this would need to be revised.

# %%
agency_product_workstation_gbdf = master_df.groupby(by=["Agency", "Product_Workstation"], axis=0)
agency_product_workstation_usage_df = agency_product_workstation_gbdf.sum()
# agency_product_workstation_usage_df = agency_product_workstation_gbdf.agg(np.sum)


agency_product_workstation_count = agency_product_workstation_gbdf["Product_Workstation"].agg(np.count_nonzero)
agency_product_workstation_count.name = "Frequency"
product_workstation_report = agency_product_workstation_usage_df.join(other=agency_product_workstation_count, how="left")

# %%
agency_product_workstation_usage_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 2572 entries, (CHART, ArcGIS Desktop Advanced_chartgbmap1) to (SHA, Workflow Manager_shaoppelte12130)
# Data columns (total 1 columns):
# Total usage time (hours)    2572 non-null float64
# dtypes: float64(1)
# memory usage: 128.0+ KB

# %% [markdown]
# ## Product_Username Report

# %%
agency_product_username_gbdf = master_df.groupby(by=["Agency", "Product_Username"], axis=0)
agency_product_username_usage_df = agency_product_username_gbdf.agg(np.sum)
agency_product_username_count = agency_product_username_gbdf["Product_Username"].agg(np.count_nonzero)
agency_product_username_count.name = "Frequency"
product_username_report = agency_product_username_usage_df.join(other=agency_product_username_count, how="left")

# %%
agency_product_username_usage_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 2295 entries, (CHART, ArcGIS Desktop Advanced_chart_sql) to (SHA, Workflow Manager_activated license(s))
# Data columns (total 1 columns):
# Total usage time (hours)    2295 non-null float64
# dtypes: float64(1)
# memory usage: 121.8+ KB

# %% [markdown]
# ## Evaluation of Product Use by Agency

# %% [markdown]
# TODO: Need to add the ProductLabel field to these reports.

# %% [markdown]
# #### Workstation and Username - Per Product Per Agency Report

# %%
agency_product_gbdf = master_df.groupby(by=["Agency", "Product"], axis=0)
agency_product_usage_df = agency_product_gbdf.agg(np.sum)
agency_product_count_series = agency_product_gbdf["Product"].agg(np.count_nonzero)
agency_product_count_series.name = "Frequency"

agency_username_count_series = agency_product_gbdf["User Name"].nunique()
agency_username_count_series.name = "Unique Usernames"

# Code preserved in case wanted to produce two separate reports
# agency_product_count_report = agency_product_usage_df.join(other=agency_product_count_series, 
#                                                            how="left").join(other=agency_username_count_series, 
#                                                                             how="left")

agency_workstation_count_series = agency_product_gbdf["Workstation"].nunique()
agency_workstation_count_series.name = "Unique Workstations"
agency_product_count_report = agency_product_usage_df.join(other=agency_product_count_series, 
                                                           how="left").join(other=agency_workstation_count_series, 
                                                                            how="left").join(other=agency_username_count_series, 
                                                                            how="left")
# agency_product_count_report.info()

# %% [markdown]
# ## Peak Usage Report

# %%
peak_usage_gbdf = master_df.groupby(by=["Agency", "Date", "Product"], axis=0)
usernames_per_day_series = peak_usage_gbdf["User Name"].nunique()
usernames_per_day_series.name = "Unique Usernames"
usernames_per_day_df = usernames_per_day_series.to_frame()
usernames_per_day_gbdf = usernames_per_day_df.groupby(by=["Agency", "Product"], axis=0)
peak_usage_report = usernames_per_day_gbdf.max().rename(columns={"Unique Usernames": "Max Licenses"})

# %% [markdown]
# #### Inspect for Specific Agency Product Usage
# Use the below code to verify the findings above for each agencies max usage across all dates a product was used by that agency

# %%
 # EDIT MY VALUES
agency_abbreviation_you_want_to_check = "SHA"
product_label_you_want_to_check = "ArcGIS Desktop Advanced"

# %%
try:
    agency_isolation_df = usernames_per_day_df.xs(key=agency_abbreviation_you_want_to_check, axis=0, level=0)
    product_isolation_series = agency_isolation_df.xs(key=product_label_you_want_to_check, axis=0, level=1).agg(np.max)
except KeyError as ke:
    print("Key Error occurred. {key} not found. Try again.".format(key=ke))
product_isolation_series.name = "{} - {}".format(agency_abbreviation_you_want_to_check, product_label_you_want_to_check)
product_isolation_series
# Out:
# Unique Usernames    40
# Name: SHA - ArcGIS Desktop Advanced, dtype: int64

# %% [markdown]
# ## Output Reports to Excel File

# %%
output_excel_file_name = "TEST_OUTPUT.xlsx"

# %%
with pd.ExcelWriter(path=output_excel_file_name, datetime_format="YYYY-MM-DD") as writer:
    product_workstation_report.to_excel(writer, sheet_name="Product Workstation")
    product_username_report.to_excel(writer, sheet_name="Product Username")
    agency_product_count_report.to_excel(writer, sheet_name="Agency Product Use Evaluation")
    peak_usage_report.to_excel(writer, sheet_name="Peak Usage")
